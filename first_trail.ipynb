# %%
import pandas as pd

# %%
pd.read_csv("C:\Users\harsh\Desktop\PG Datascience&MI&NN\data\employee_dataset.csv",set="\t")
# Out:
#   File "<ipython-input-11-9c034b7a4b48>", line 1
#     pd.read_csv("C:\Users\harsh\Desktop\PG Datascience&MI&NN\data\employee_dataset.csv",set="\t")
#                 ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/Restaurant_Reviews.tsv",sep="\t")
# Out:
#                                                 Review  Liked
# 0                             Wow... Loved this place.      1
# 1                                   Crust is not good.      0
# 2            Not tasty and the texture was just nasty.      0
# 3    Stopped by during the late May bank holiday of...      1
# 4    The selection on the menu was great and so wer...      1
# ..                                                 ...    ...
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0
#
# [1000 rows x 2 columns]

# %%
pd.read_csv("C:\Users\harsh\Desktop\PG Datascience&MI&NN\data\1000 Records.csv")
# Out:
#   File "<ipython-input-12-4bf80ce6c837>", line 1
#     pd.read_csv("C:\Users\harsh\Desktop\PG Datascience&MI&NN\data\1000 Records.csv")
#                 ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
